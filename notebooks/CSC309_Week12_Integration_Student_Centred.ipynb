# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakinat-Folorunso/OOU_CSC309_Artificial_Intelligence/blob/main/notebooks/CSC309_Week12_Integration_Student_Centred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CSC309 – Artificial Intelligence
# **Week 12 Lab:** Integration, Debugging & Mock Practical
#
# **Instructor:** Dr Sakinat Folorunso
# **Title:** Associate Professor of AI Systems and FAIR Data **Department:** Computer Sciences, Olabisi Onabanjo University, Ago-Iwoye, Ogun State, Nigeria
#
# **Course Code:** CSC 309
#
# **Practical Week: 12** – Integration
#
# **Mode:** Student‑centred, hands‑on in Google Colab
#
# > Every code cell is commented line‑by‑line so you can follow the logic precisely.

# %% [markdown]
# ## How to use this notebook
# 1. Start with the **Group Log** and **Do Now**.
# 2. Run the **Setup** cell once.
# 3. Work through **Tasks**. Edit only cells marked **`# TODO(Student)`**.
# 4. Use **Quick Checks** to test your understanding.
# 5. Finish with the **Reflection**. If you finish early, try the **Extensions**.

# %%
#@title 🧑🏽‍🤝‍🧑🏾 Group Log (fill before you start)
# The '#@param' annotations create form fields in Colab for easy input.

group_members = "Type names here"  #@param {type:"string"}  # Names of teammates
roles_notes = "Driver/Navigator, decisions, questions"  #@param {type:"string"}  # Short working notes

print("👥 Group:", group_members)        # Echo the group list for confirmation
print("📝 Notes:", roles_notes)          # Echo the notes so they're preserved in output

# %% [markdown]
# ### Learning Objectives
# - Integrate methods from search, KR, NLP, vision, and agents.
# - Practice debugging and communicating results under time limits.

# %%
#@title 🔧 Setup
# Week 12 uses only Python's standard library for the checklist and reflection.
print("✅ Setup complete for Week 12.")

# %%
#@title 🧪 Mock tasks checklist (line‑by‑line)
checklist = [                                                     # A list of short integration tasks
    "Implement a small heuristic and explain why it's admissible.",
    "Add 3 expert‑system rules to handle a new case.",
    "Improve spam accuracy by +1% (document what you changed).",
    "Tune boids parameters to reduce collisions by 20%.",
]
for i, t in enumerate(checklist, 1):                              # Enumerate tasks starting at 1
    print(f"{i}. {t}")                                            # Print the numbered task

# %%
#@title 📝 Final Reflection (edit inside the triple quotes)
reflection = """
- Two concepts that connected strongly for me were …
- If I had four more weeks, I would build … (outline steps, risks, and resources).
"""
print(reflection.strip())                                         # Echo your reflection
